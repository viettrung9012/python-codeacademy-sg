# %%
#  Input variables bellow 
#  (You can use as many variables as you want)
coffee_unit_price = 20/100
tea_unit_price = 18/100
co_milk_unit_price = 32/100
ev_milk_unit_price = 25/100
sugar_unit_price = 15/100

monthly_rent = 2800
yearly_rent = 12*monthly_rent

#  Exercise 1
#   - Print the answer to this question: Is an "Iced Kopi C Gao" more profitable than a "Hot Teh Siew Tai" ?
kopi_c_gao_cost = 3*coffee_unit_price + 2*sugar_unit_price + 2*ev_milk_unit_price
kopi_c_gao_price = 2
kopi_c_gao_profit = kopi_c_gao_price - kopi_c_gao_cost
teh_st_cost = 3*tea_unit_price + 0.5*sugar_unit_price + 2*co_milk_unit_price
teh_st_price = 2.5
teh_st_profit = teh_st_price - teh_st_cost

print("Iced Kopi C Gao margin:", kopi_c_gao_profit)
print("Hot Teh Siew Tai margin:", teh_st_profit)
print("Is an \"Iced Kopi C Gao\" more profitable than a \"Hot Teh Siew Tai\":", kopi_c_gao_profit > teh_st_profit)

#  Exercise 2
#   - Print the number of "Yuan Yang C Kosong" you need to sell in order to pay your rent for a year.
yycko_cost = 1.5*coffee_unit_price + 1.5*tea_unit_price + 2*ev_milk_unit_price
yycko_price = 3
yycko_profit = yycko_price - yycko_cost

print("Yuan Yang C Kosong margin:", yycko_profit)
print("Number of \"Yuan Yang C Kosong\" I need to sell in order to pay my rent for a year:", int(yearly_rent/yycko_profit))

#  Exercise 3
#   - Knowing that:
#      - I buy 1000 units of each ingredient a day
#      - At half-day, I've sold 125 "Kopis O", 97 "Teh C Gao", and 83 "Yuan Yang Siew Tai"
#      - How many regular "Kopis" can I make in the afternoon until I run out of an ingredient ?
#      - How many units of each ingredient will I have left at the end of the day after making all these Kopis ?
coffee_units_left = 1000 - (125*3 + 83*1.5)
tea_units_left = 1000 - (97*3 + 83*1.5)
sugar_units_left = 1000 - (125 + 97*2 + 83*0.5)
co_milk_units_left = 1000 - (83*2)
ev_milk_units_left = 1000 - (97*2)

print("Coffee units left:", coffee_units_left)
print("Tea units left:", tea_units_left)
print("Sugar units left:", sugar_units_left)
print("Condensed milk units left:", co_milk_units_left)
print("Evaporated milk units left:", ev_milk_units_left)

kopis_can_make = int(coffee_units_left / 3)
print("Number of Kopis I can make in the afternoon until I run out of an ingredient :", kopis_can_make)

coffee_units_left = coffee_units_left - (kopis_can_make*3)
sugar_units_left = sugar_units_left - (kopis_can_make*1)
co_milk_units_left = co_milk_units_left - (kopis_can_make*2)
print("Coffee units left EOD:", coffee_units_left)
print("Sugar units left EOD:", sugar_units_left)
print("Condensed milk units left EOD:", co_milk_units_left)

#  Exercise 4
#   - From a Singaporean point of view, does a Teh Tarik taste better in Johor Bahru?
